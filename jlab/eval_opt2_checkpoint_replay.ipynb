# %% [markdown]
# ## Replaying Checkpoints
#
# - load a checkpoint and replay it back.

# %%
from langchain_openai import ChatOpenAI
from langgraph.graph import START, END, StateGraph
from pydantic import BaseModel, Field
from typing import TypedDict, Optional
from langgraph.checkpoint.memory import MemorySaver
from dotenv import load_dotenv

load_dotenv()

# -----------------------------
# STATE
# -----------------------------
class GraphState(TypedDict):
    topic: str
    draft: str
    feedback: str
    score: int
    iteration: int
    prev_score: int


# -----------------------------
# LLM
# -----------------------------
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.7
)


# -----------------------------
# STRUCTURED EVALUATION
# -----------------------------
class Evaluation(BaseModel):
    score: int = Field(ge=1, le=10)
    feedback: str = Field(description="Clear bullet-point improvements")


evaluator_llm = llm.with_structured_output(Evaluation)


# -----------------------------
# NODE 1: GENERATE
# -----------------------------
def generate(state: GraphState):
    print(f"\n🧠 Generating (iteration {state.get('iteration', 0)})")

    topic = state.get("topic", "")
    draft = state.get("draft", "")
    feedback = state.get("feedback", "")

    # First draft
    if not draft:
        prompt = f"""
You are a professional business writer.

Write a clear, structured article on:

Topic: {topic}

Requirements:
- Use headings
- Be concise and professional
- Make it suitable for an organizational audience
"""
    else:
        # Improvement loop
        prompt = f"""
You are a senior editor improving content.

Rewrite the article using the feedback below.

Current Draft:
{draft}

Feedback:
{feedback}

Return a significantly improved version.
"""

    response = llm.invoke(prompt).content

    return {
        "draft": response,
        "iteration": state.get("iteration", 0) + 1
    }


# -----------------------------
# NODE 2: EVALUATE
# -----------------------------
def evaluate(state: GraphState):
    print("📊 Evaluating draft...")

    prompt = f"""
You are a strict editorial reviewer.

Evaluate the following content:

Content:
{state['draft']}

Return:
- Score (1–10)
- Bullet-point feedback for improvement
"""

    result = evaluator_llm.invoke(prompt)

    return {
        "score": result.score,
        "feedback": result.feedback
    }


# -----------------------------
# NODE 3: DECISION LOGIC
# -----------------------------
def should_continue(state: GraphState):
    score = state["score"]
    iteration = state["iteration"]
    prev_score = state.get("prev_score", 0)

    print(f"🔁 Score: {score} | Prev: {prev_score} | Iteration: {iteration}")

    # Stop conditions
    if iteration >= 5:
        return "end"

    if score >= 8:
        return "end"

    if score <= prev_score:
        return "end"  # stagnation stop

    return "generate"

# %%
# -----------------------------
# GRAPH BUILDING
# -----------------------------
builder = StateGraph(GraphState)

builder.add_node("generate", generate)
builder.add_node("evaluate", evaluate)

builder.add_edge(START, "generate")
builder.add_edge("generate", "evaluate")

builder.add_conditional_edges(
    "evaluate",
    should_continue,
    {
        "generate": "generate",
        "end": END
    }
)

#memory Configuration
checkpointer = MemorySaver()
config = {
    "configurable":{
        "thread_id": "eval01"
    }
}

graph = builder.compile(checkpointer=checkpointer)

# %%
graph

# %%
# -----------------------------
# RUN
# -----------------------------
response = graph.invoke({
    "topic": "Leadership Meetings in Modern Organizations",
    "draft": "",
    "feedback": "",
    "score": 0,
    "iteration": 0,
    "prev_score": 0
},
config=config)

# print("\n✅ FINAL OUTPUT:\n")
# print(response["draft"])
# print("\n⭐ Final Score:", response["score"])
# Out:
# 🧠 Generating (iteration 0)
# 📊 Evaluating draft...
# c:\lang1\venvi\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [input_value=Evaluation(score=7, feedb...or better readability."), input_type=Evaluation])
#   return self.__pydantic_serializer__.to_python(
# 🔁 Score: 7 | Prev: 0 | Iteration: 1
#
# 🧠 Generating (iteration 1)
# 📊 Evaluating draft...
# c:\lang1\venvi\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [input_value=Evaluation(score=7, feedb...he article’s claims.'), input_type=Evaluation])
#   return self.__pydantic_serializer__.to_python(
# 🔁 Score: 7 | Prev: 0 | Iteration: 2
#
# 🧠 Generating (iteration 2)
# 📊 Evaluating draft...
# 🔁 Score: 8 | Prev: 0 | Iteration: 3
# c:\lang1\venvi\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [input_value=Evaluation(score=8, feedb... the original sources.'), input_type=Evaluation])
#   return self.__pydantic_serializer__.to_python(

# %%
#VISUALIZED THE STATE OF THE GRAPH FROM DIFFERENT SNAPSHOT
#

def print_snapshot_data(snapshot_state):
    thread_id = snapshot_state.config['configurable']['thread_id']
    print("Thread ID:", thread_id)

    checkpoint_id = snapshot_state.config['configurable']['checkpoint_id']
    print("SNAPSHOT ID:", checkpoint_id)


    next_node = snapshot_state.next if snapshot_state.next else "None (Workflow Complete)"
    print("Next Node:", next_node)

    print('-'*50)
    print('State Values:')
    print('-'*50)
    print('Title:', snapshot_state.values.get('topic',''))
    print('Iterations: ', snapshot_state.values.get('iteration',0))
    print('Feedback: ', snapshot_state.values.get('feedback',''))
    print('Draft: ', f'{snapshot_state.values.get('draft','')[100:250]}...')

# get the current state of the graph (this is suppose to be the final state, except you are doing a human in the loop stuff)
print('-'*50)
print('Current Graph State')
print('-'*50)

# get the current state (snapshot)
current_state = graph.get_state(config)

print_snapshot_data(current_state)
###########################################################################################
###########################################################################################

# REPLAY A CHECKPOINT (NODE)
# input [0] -> start node [1]-->generate [2] --> evaluate[3]

#get all checkpoint history as a list
checkpoint_history = list(graph.get_state_history(config))
#get the checkpoint to replay from the checkpoint list (in this instace the 4 index - [3]) - this is evaluate checkpoint
checkpoint_to_replay = checkpoint_history[3]
#get the checkpoint_id for evaluate checkpoint
evaluate_checkpoint_id = checkpoint_to_replay.config["configurable"]["checkpoint_id"]
thread_id = checkpoint_to_replay.config['configurable']['thread_id']

replay_config = {
    "configurable":{
        "thread_id": thread_id,
        "checkpoint_id": evaluate_checkpoint_id
    }
}

print(f"\n Replaying from: {evaluate_checkpoint_id} ...")
print("This will re-evaluate the draft")

replay = graph.invoke(None, replay_config)

print("Replay Complete")
print("DRAFT:\n", replay['draft'])
print("\nFEEDBACK:\n", replay['feedback'])
# Out:
# --------------------------------------------------
# Current Graph State
# --------------------------------------------------
# Thread ID: eval01
# SNAPSHOT ID: 1f137536-0f03-680a-800e-201988c808db
# Next Node: None (Workflow Complete)
# --------------------------------------------------
# State Values:
# --------------------------------------------------
# Title: Leadership Meetings in Modern Organizations
# Iterations:  3
# Feedback:  - **Clarity and Focus**: While the content is generally clear, consider using more concise language in some sections to enhance readability.
# - **Examples**: The provided examples are relevant but could be expanded with more specific data or outcomes to strengthen the points made.
# - **Visual Elements**: Incorporating visual aids (like charts or diagrams) could help illustrate key concepts and improve engagement.
# - **Case Study**: The case study is a strong addition but could benefit from more detailed metrics or qualitative outcomes.
# - **References**: Ensure that the links in the references section are correctly formatted or functional to provide readers with easy access to the original sources.
# Draft:  ronment, effective leadership meetings are more crucial than ever. According to a study by the Harvard Business Review, organizations that prioritize ...
#
#  Replaying from: 1f137535-10f0-6f65-800b-08950bafe9b1 ...
# This will re-evaluate the draft
# 📊 Evaluating draft...
# 🔁 Score: 8 | Prev: 0 | Iteration: 2
# Replay Complete
# DRAFT:
#  # Leadership Meetings in Modern Organizations
#
# Leadership meetings are a cornerstone of effective management in contemporary organizations. These gatherings provide an essential platform for decision-making, strategic planning, and team alignment. In this article, we will explore the purpose, structure, best practices, and challenges associated with leadership meetings in modern organizations, supplemented by examples and strategies to enhance engagement.
#
# ## Purpose of Leadership Meetings
#
# Leadership meetings serve multiple critical functions within an organization, including:
#
# 1. **Strategic Alignment**: These meetings ensure that departmental goals align with the organization's overall strategy. For example, a tech company may hold quarterly leadership meetings to ensure that product development aligns with market trends and customer feedback.
#
# 2. **Decision-Making**: Leadership meetings provide a forum for leaders to discuss and make critical decisions that impact the organization. A notable instance is when a healthcare organization’s leadership team convened to decide on adopting telehealth services, weighing the potential benefits against operational challenges.
#
# 3. **Communication**: These gatherings enhance communication among executives, ensuring that information flows smoothly across various levels of the organization. For instance, regular meetings can help bridge the gap between marketing and sales teams, fostering collaboration on campaigns.
#
# 4. **Problem-Solving**: They allow leaders to collaboratively address challenges and develop innovative solutions. A retail chain, for example, may use a leadership meeting to brainstorm strategies for improving customer experience after receiving negative feedback.
#
# ## Structure of Effective Leadership Meetings
#
# To maximize productivity, leadership meetings should be well-structured. Key elements of an effective meeting structure include:
#
# 1. **Agenda**: A clear agenda should be circulated in advance, outlining the topics to be covered and the time allocated for each item. For example, an agenda might include time slots for reviewing sales performance, discussing ongoing projects, and brainstorming new initiatives.
#
# 2. **Participants**: Involve relevant stakeholders from various departments to ensure diverse perspectives are considered. For a successful product launch meeting, including representatives from marketing, sales, and product development can provide comprehensive insights.
#
# 3. **Time Management**: Assign a designated timekeeper to ensure discussions stay on track and that all agenda items are addressed. This practice ensures that critical topics receive adequate attention without dragging on unnecessarily.
#
# 4. **Action Items**: Conclude each meeting with a summary of action items, assigning responsibilities and deadlines for follow-up. For instance, if a decision is made to implement a new software tool, the meeting should end with clear ownership and timelines for training and rollout.
#
# ## Best Practices for Leadership Meetings
#
# To enhance the effectiveness of leadership meetings, consider the following best practices:
#
# ### Set Clear Objectives
# Define the goals of each meeting to ensure that discussions remain focused and productive. For instance, if the objective is to develop a marketing strategy, ensure that all discussions revolve around that goal.
#
# ### Encourage Open Dialogue
# Foster an environment where all participants feel comfortable sharing their ideas and concerns. Techniques such as round-robin sharing or anonymous feedback tools can help ensure that everyone's voice is heard.
#
# ### Utilize Technology
# Leverage collaboration tools and video conferencing platforms to facilitate remote participation and enhance engagement. Tools like Miro or Microsoft Teams can help in visualizing ideas and keeping everyone on the same page, especially in hybrid work environments.
#
# ### Review and Reflect
# Regularly assess the effectiveness of meetings through feedback and adjust formats as needed to improve outcomes. Conducting surveys after meetings can provide insights into what worked well and what could be improved.
#
# ## Challenges in Leadership Meetings
#
# While leadership meetings are crucial, they can also present challenges:
#
# ### Time Constraints
# Leaders often face busy schedules, which can limit the frequency and duration of meetings. To mitigate this, organizations can adopt shorter, more frequent meetings instead of longer, less frequent ones.
#
# ### Dominance by Certain Voices
# Some participants may overshadow others, stifling diverse input and discussion. Implementing a "silent brainstorming" session before discussions can help level the playing field by allowing everyone to contribute ideas anonymously.
#
# ### Lack of Engagement
# Without proper engagement strategies, meetings can become unproductive and overly routine. Incorporating interactive elements, such as polls or breakout discussions, can keep participants actively involved.
#
# ### Follow-Through
# Ensuring action items are completed can be difficult without accountability mechanisms in place. Tools like project management software can help track progress on assigned responsibilities.
#
# ## Conclusion
#
# Leadership meetings are vital for driving organizational success in today's fast-paced business environment. By establishing a clear structure, adhering to best practices, and addressing common challenges, organizations can enhance the effectiveness of their leadership meetings. Ultimately, these gatherings should serve as powerful tools for fostering collaboration, strategic thinking, and informed decision-making, positioning the organization for long-term success.
#
# ### References
# - Harvard Business Review. (2021). "Why Meetings Matter."
# - Gallup. (2022). "State of the Global Workplace: 2022 Report."
# - McKinsey & Company. (2022). "The Future of Work: Leadership in a Hybrid World."
#
# FEEDBACK:
#  - **Clarity and Conciseness**: While the content is informative, some sections could be more concise. Aim for brevity in explanations to maintain reader engagement.
# - **Examples**: Provide more varied examples across different industries to enhance relatability and applicability.
# - **Visuals**: Consider incorporating visual aids, such as charts or infographics, to break up text and illustrate key points effectively.
# - **Engagement Strategies**: Expand on specific strategies for enhancing engagement during meetings, perhaps by including case studies or testimonials.
# - **References Formatting**: Ensure that the references are formatted consistently and include more recent studies or articles to bolster credibility.
# c:\lang1\venvi\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [input_value=Evaluation(score=8, feedb...o bolster credibility.'), input_type=Evaluation])
#   return self.__pydantic_serializer__.to_python(
